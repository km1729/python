# %%
# word = tuple(input("What's in your mind? : "))
word='hello'
hist = {}

for key in word:
  hist[key] = hist.get(key,0)+1

hist
# Out:
# {'h': 1,
#  'e': 4,
#  'l': 3,
#  'o': 1,
#  ',': 2,
#  ' ': 2,
#  'a': 2,
#  'p': 2,
#  'K': 1,
#  'y': 1,
#  'c': 1}
